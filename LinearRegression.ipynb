# %%
import pandas as pd
import numpy as np
import datetime as dt
import dateutil.relativedelta as rd
import matplotlib.pyplot as plt

# %%
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error as mse
import statsmodels.api as sm
from scipy import stats

# %%
# Display all the columns for the dataframes (not-truncated)
pd.set_option("display.max_columns", None)
# Format floats better
pd.options.display.float_format = '{:,.4f}'.format

# %%
covid_df = pd.read_csv("Resources/covid_data.csv")
covid_df
# Out:
#         Unnamed: 0        id        date  confirmed  deaths  recovered  \
# 0            26885  0094b645  2020-01-22        NaN     NaN        NaN
# 1            26886  0094b645  2020-01-23        NaN     NaN        NaN
# 2            26887  0094b645  2020-01-24        NaN     NaN        NaN
# 3            26888  0094b645  2020-01-25        NaN     NaN        NaN
# 4            26889  0094b645  2020-01-26        NaN     NaN        NaN
# ...            ...       ...         ...        ...     ...        ...
# 162176      113401  fd169ad6  2022-01-07 6,767.0000 67.0000        NaN
# 162177      113402  fd169ad6  2022-01-08 6,823.0000 67.0000        NaN
# 162178      113403  fd169ad6  2022-01-09 6,887.0000 67.0000 6,163.0000
# 162179      113404  fd169ad6  2022-01-10 6,915.0000 67.0000 6,230.0000
# 162180      113405  fd169ad6  2022-01-11 6,916.0000 67.0000        NaN
#
#              tests    vaccines  people_vaccinated  people_fully_vaccinated  \
# 0              NaN         NaN                NaN                      NaN
# 1              NaN         NaN                NaN                      NaN
# 2              NaN         NaN                NaN                      NaN
# 3              NaN         NaN                NaN                      NaN
# 4              NaN         NaN                NaN                      NaN
# ...            ...         ...                ...                      ...
# 162176 90,009.0000 64,648.0000        26,229.0000              25,701.0000
# 162177 90,204.0000 64,796.0000        26,377.0000              25,702.0000
# 162178 90,383.0000 64,796.0000        26,377.0000              25,702.0000
# 162179 90,433.0000 65,310.0000        26,385.0000              25,738.0000
# 162180         NaN         NaN                NaN                      NaN
#
#         hosp  icu  vent  school_closing  workplace_closing  cancel_events  \
# 0        NaN  NaN   NaN             NaN                NaN            NaN
# 1        NaN  NaN   NaN             NaN                NaN            NaN
# 2        NaN  NaN   NaN             NaN                NaN            NaN
# 3        NaN  NaN   NaN             NaN                NaN            NaN
# 4        NaN  NaN   NaN             NaN                NaN            NaN
# ...      ...  ...   ...             ...                ...            ...
# 162176   NaN  NaN   NaN             NaN                NaN            NaN
# 162177   NaN  NaN   NaN             NaN                NaN            NaN
# 162178   NaN  NaN   NaN             NaN                NaN            NaN
# 162179   NaN  NaN   NaN             NaN                NaN            NaN
# 162180   NaN  NaN   NaN             NaN                NaN            NaN
#
#         gatherings_restrictions  transport_closing  stay_home_restrictions  \
# 0                           NaN                NaN                     NaN
# 1                           NaN                NaN                     NaN
# 2                           NaN                NaN                     NaN
# 3                           NaN                NaN                     NaN
# 4                           NaN                NaN                     NaN
# ...                         ...                ...                     ...
# 162176                      NaN                NaN                     NaN
# 162177                      NaN                NaN                     NaN
# 162178                      NaN                NaN                     NaN
# 162179                      NaN                NaN                     NaN
# 162180                      NaN                NaN                     NaN
#
#         internal_movement_restrictions  international_movement_restrictions  \
# 0                                  NaN                                  NaN
# 1                                  NaN                                  NaN
# 2                                  NaN                                  NaN
# 3                                  NaN                                  NaN
# 4                                  NaN                                  NaN
# ...                                ...                                  ...
# 162176                             NaN                                  NaN
# 162177                             NaN                                  NaN
# 162178                             NaN                                  NaN
# 162179                             NaN                                  NaN
# 162180                             NaN                                  NaN
#
#         information_campaigns  testing_policy  contact_tracing  \
# 0                         NaN             NaN              NaN
# 1                         NaN             NaN              NaN
# 2                         NaN             NaN              NaN
# 3                         NaN             NaN              NaN
# 4                         NaN             NaN              NaN
# ...                       ...             ...              ...
# 162176                    NaN             NaN              NaN
# 162177                    NaN             NaN              NaN
# 162178                    NaN             NaN              NaN
# 162179                    NaN             NaN              NaN
# 162180                    NaN             NaN              NaN
#
#         facial_coverings  vaccination_policy  elderly_people_protection  \
# 0                    NaN                 NaN                        NaN
# 1                    NaN                 NaN                        NaN
# 2                    NaN                 NaN                        NaN
# 3                    NaN                 NaN                        NaN
# 4                    NaN                 NaN                        NaN
# ...                  ...                 ...                        ...
# 162176               NaN                 NaN                        NaN
# 162177               NaN                 NaN                        NaN
# 162178               NaN                 NaN                        NaN
# 162179               NaN                 NaN                        NaN
# 162180               NaN                 NaN                        NaN
#
#         government_response_index  stringency_index  containment_health_index  \
# 0                             NaN               NaN                       NaN
# 1                             NaN               NaN                       NaN
# 2                             NaN               NaN                       NaN
# 3                             NaN               NaN                       NaN
# 4                             NaN               NaN                       NaN
# ...                           ...               ...                       ...
# 162176                        NaN               NaN                       NaN
# 162177                        NaN               NaN                       NaN
# 162178                        NaN               NaN                       NaN
# 162179                        NaN               NaN                       NaN
# 162180                        NaN               NaN                       NaN
#
#         economic_support_index  administrative_area_level  \
# 0                          NaN                          1
# 1                          NaN                          1
# 2                          NaN                          1
# 3                          NaN                          1
# 4                          NaN                          1
# ...                        ...                        ...
# 162176                     NaN                          1
# 162177                     NaN                          1
# 162178                     NaN                          1
# 162179                     NaN                          1
# 162180                     NaN                          1
#
#        administrative_area_level_1  administrative_area_level_2  \
# 0                      Saint Lucia                          NaN
# 1                      Saint Lucia                          NaN
# 2                      Saint Lucia                          NaN
# 3                      Saint Lucia                          NaN
# 4                      Saint Lucia                          NaN
# ...                            ...                          ...
# 162176               Liechtenstein                          NaN
# 162177               Liechtenstein                          NaN
# 162178               Liechtenstein                          NaN
# 162179               Liechtenstein                          NaN
# 162180               Liechtenstein                          NaN
#
#         administrative_area_level_3  latitude  longitude   population  \
# 0                               NaN   13.9094   -60.9789 181,889.0000
# 1                               NaN   13.9094   -60.9789 181,889.0000
# 2                               NaN   13.9094   -60.9789 181,889.0000
# 3                               NaN   13.9094   -60.9789 181,889.0000
# 4                               NaN   13.9094   -60.9789 181,889.0000
# ...                             ...       ...        ...          ...
# 162176                          NaN   47.1400     9.5500  37,910.0000
# 162177                          NaN   47.1400     9.5500  37,910.0000
# 162178                          NaN   47.1400     9.5500  37,910.0000
# 162179                          NaN   47.1400     9.5500  37,910.0000
# 162180                          NaN   47.1400     9.5500  37,910.0000
#
#        iso_alpha_3 iso_alpha_2  iso_numeric iso_currency  key_local  \
# 0              LCA          LC     662.0000          XCD        NaN
# 1              LCA          LC     662.0000          XCD        NaN
# 2              LCA          LC     662.0000          XCD        NaN
# 3              LCA          LC     662.0000          XCD        NaN
# 4              LCA          LC     662.0000          XCD        NaN
# ...            ...         ...          ...          ...        ...
# 162176         LIE          LI     438.0000          CHF        NaN
# 162177         LIE          LI     438.0000          CHF        NaN
# 162178         LIE          LI     438.0000          CHF        NaN
# 162179         LIE          LI     438.0000          CHF        NaN
# 162180         LIE          LI     438.0000          CHF        NaN
#
#                 key_google_mobility key_apple_mobility key_jhu_csse  key_nuts  \
# 0                               NaN                NaN           LC       NaN
# 1                               NaN                NaN           LC       NaN
# 2                               NaN                NaN           LC       NaN
# 3                               NaN                NaN           LC       NaN
# 4                               NaN                NaN           LC       NaN
# ...                             ...                ...          ...       ...
# 162176  ChIJ_S9HHUQxm0cRibFa3Ta16mA                NaN           LI       NaN
# 162177  ChIJ_S9HHUQxm0cRibFa3Ta16mA                NaN           LI       NaN
# 162178  ChIJ_S9HHUQxm0cRibFa3Ta16mA                NaN           LI       NaN
# 162179  ChIJ_S9HHUQxm0cRibFa3Ta16mA                NaN           LI       NaN
# 162180  ChIJ_S9HHUQxm0cRibFa3Ta16mA                NaN           LI       NaN
#
#        key_gadm
# 0           LCA
# 1           LCA
# 2           LCA
# 3           LCA
# 4           LCA
# ...         ...
# 162176      LIE
# 162177      LIE
# 162178      LIE
# 162179      LIE
# 162180      LIE
#
# [162181 rows x 48 columns]

# %%
covid_df = covid_df.groupby(["date"])[[
    "deaths",
    "vaccines",
    "people_vaccinated",
    "people_fully_vaccinated",
    "school_closing",
    "workplace_closing",
]].sum()
covid_df.index = pd.to_datetime(covid_df.index)
covid_df
# Out:
#                    deaths           vaccines  people_vaccinated  \
# date
# 2020-01-01         0.0000             0.0000             0.0000
# 2020-01-02         0.0000             0.0000             0.0000
# 2020-01-03         0.0000             0.0000             0.0000
# 2020-01-04         0.0000             0.0000             0.0000
# 2020-01-05         0.0000             0.0000             0.0000
# ...                   ...                ...                ...
# 2022-01-07 5,286,317.0000 7,259,162,583.0000 3,480,744,034.0000
# 2022-01-08 5,290,633.0000 7,473,747,216.0000 2,320,880,247.0000
# 2022-01-09 5,293,761.0000 7,769,900,363.0000 2,410,029,675.0000
# 2022-01-10 5,299,436.0000 7,507,184,227.0000 2,280,075,739.0000
# 2022-01-11 1,110,751.0000   974,974,216.0000   463,050,665.0000
#
#             people_fully_vaccinated  school_closing  workplace_closing
# date
# 2020-01-01                   0.0000          0.0000             0.0000
# 2020-01-02                   0.0000          0.0000             0.0000
# 2020-01-03                   0.0000          0.0000             0.0000
# 2020-01-04                   0.0000          0.0000             0.0000
# 2020-01-05                   0.0000          0.0000             0.0000
# ...                             ...             ...                ...
# 2022-01-07       3,013,097,777.0000         43.0000            61.0000
# 2022-01-08       1,866,975,858.0000         39.0000            53.0000
# 2022-01-09       2,010,571,139.0000         35.0000            45.0000
# 2022-01-10       1,903,643,200.0000         26.0000            36.0000
# 2022-01-11         397,899,364.0000          0.0000             0.0000
#
# [742 rows x 6 columns]

# %%
feature_columns = [
    "vaccines",
    "people_vaccinated",
    "people_fully_vaccinated",
#     "school_closing",
#     "workplace_closing",
]

# Select the target feature
target_feature = "deaths"

# %%
X = covid_df[feature_columns]
y = covid_df[[target_feature]].values.ravel()

# %%
from sklearn.model_selection import TimeSeriesSplit

def train_time_serise(X,y,testing_size):
    model = LinearRegression()
    summary = {
        "rmse":[],
        "train_start":[],
        "train_end":[],
        "test_start":[],
        "test_end":[],
    }
    tscv = TimeSeriesSplit(n_splits=int(X.shape[0]/testing_size) - 1, test_size=testing_size)
    for train_index, test_index in tscv.split(X):
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y[train_index], y[test_index]
        model.fit(X_train,y_train)
        y_hat = model.predict(X_test)
        summary["rmse"].append(np.sqrt(mse(y_hat,y_test)))
        summary["train_start"].append(str(X_train.index.min().date()))
        summary["train_end"].append(str(X_train.index.max().date()))
        summary["test_start"].append(str(X_test.index.min().date()))
        summary["test_end"].append(str(X_test.index.max().date()))
    return model, pd.DataFrame(summary)

# %%
split = 30
model, time_serise_summary_df = train_time_serise(X,y,split)
time_serise_summary_df
# Out:
#                    rmse train_start   train_end  test_start    test_end
# 0            5,884.3397  2020-01-01  2020-02-21  2020-02-22  2020-03-22
# 1           93,742.4525  2020-01-01  2020-03-22  2020-03-23  2020-04-21
# 2          221,319.3924  2020-01-01  2020-04-21  2020-04-22  2020-05-21
# 3          302,021.5668  2020-01-01  2020-05-21  2020-05-22  2020-06-20
# 4          386,581.1030  2020-01-01  2020-06-20  2020-06-21  2020-07-20
# 5          497,823.7324  2020-01-01  2020-07-20  2020-07-21  2020-08-19
# 6        5,089,811.6149  2020-01-01  2020-08-19  2020-08-20  2020-09-18
# 7        3,498,355.5958  2020-01-01  2020-09-18  2020-09-19  2020-10-18
# 8        2,991,732.5531  2020-01-01  2020-10-18  2020-10-19  2020-11-17
# 9  115,998,389,690.1869  2020-01-01  2020-11-17  2020-11-18  2020-12-17
# 10     554,277,897.0397  2020-01-01  2020-12-17  2020-12-18  2021-01-16
# 11       9,160,066.4922  2020-01-01  2021-01-16  2021-01-17  2021-02-15
# 12       1,639,768.0128  2020-01-01  2021-02-15  2021-02-16  2021-03-17
# 13         478,844.3324  2020-01-01  2021-03-17  2021-03-18  2021-04-16
# 14       4,989,290.5181  2020-01-01  2021-04-16  2021-04-17  2021-05-16
# 15       3,056,626.3432  2020-01-01  2021-05-16  2021-05-17  2021-06-15
# 16         462,926.4056  2020-01-01  2021-06-15  2021-06-16  2021-07-15
# 17         886,532.7580  2020-01-01  2021-07-15  2021-07-16  2021-08-14
# 18       3,228,262.9273  2020-01-01  2021-08-14  2021-08-15  2021-09-13
# 19       1,390,932.8604  2020-01-01  2021-09-13  2021-09-14  2021-10-13
# 20       1,214,137.5471  2020-01-01  2021-10-13  2021-10-14  2021-11-12
# 21         948,412.2998  2020-01-01  2021-11-12  2021-11-13  2021-12-12
# 22       1,078,702.6506  2020-01-01  2021-12-12  2021-12-13  2022-01-11

# %%
def linear_regression_summary(model, X, y):
    # https://stackoverflow.com/a/42677750
    coefficients = np.append(model.intercept_, model.coef_)
    predictions = model.predict(X)

    constant_name = "Constant (y-intercept)"
    X_appended = X.copy()
    X_appended[constant_name] = 1
    X_appended = X_appended.reindex(columns=[constant_name] + list(X.columns))
    
    MSE = (sum((y-predictions)**2))/(len(X_appended)-len(X_appended.columns))
    std_err = np.sqrt(MSE * (np.linalg.inv(np.dot(X_appended.T,X_appended)).diagonal()))
    t_values = coefficients / std_err
    p_values = [2*(1-stats.t.cdf(np.abs(i),(len(X_appended)-len(X_appended.iloc[0])))) for i in t_values]

    summary_df = pd.DataFrame(index = X_appended.columns)
    summary_df.index.name = "Feature"
    summary_df["Coefficients"] = coefficients
    summary_df["Standard Errors"] = std_err
    summary_df["t"] = t_values
    summary_df["P>|t|"] = p_values
    
    return summary_df

# %%
summary_df = linear_regression_summary(model,X,y)
summary_df.sort_values(by=["P>|t|"],ascending=False)
# Out:
#                           Coefficients  Standard Errors       t  P>|t|
# Feature
# vaccines                       -0.0002           0.0001 -1.9868 0.0473
# Constant (y-intercept)  1,007,053.7607      35,174.9993 28.6298 0.0000
# people_vaccinated               0.0034           0.0002 15.0901 0.0000
# people_fully_vaccinated        -0.0015           0.0002 -9.7504 0.0000

# %%
def combine_feature_with_coefficients(df,summary_df):
    cols = list(set(df.columns) & set(summary_df.index))
    data_df = df[cols].copy(deep=True)
    coeff_df = summary_df.loc[cols,"Coefficients"]
    for col in cols:
        data_df[col] = data_df[col] * coeff_df[col]
    return data_df

# %%
data_df = combine_feature_with_coefficients(covid_df,summary_df)
data_df.plot(kind="area",stacked=True,figsize=(16,9))
# Out:
# <AxesSubplot:xlabel='date'>

# %%
covid_df[[target_feature]].plot(figsize=(16,9))
# Out:
# <AxesSubplot:xlabel='date'>
